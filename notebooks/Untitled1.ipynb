# %%
import numpy as np

# %%
path = "/home/predm/skimage_segmentation/ice_masks/S1A_EW_GRDM_1SDH_20200101T074515_20200101T074619_030604_038191_EBD1.SAFE_0_0_ice_mask.npz"
data = np.load(path)
print(data.files)
# Out:
# ['ice_mask', 'labels']

# %%
labels = data["labels"]
ice_mask = data["ice_mask"]

print("labels shape:", labels.shape)
print("ice_mask shape:", ice_mask.shape)
print("labels dtype:", labels.dtype)
print("ice_mask dtype:", ice_mask.dtype)
# Out:
# labels shape: (512, 512)
# ice_mask shape: (512, 512)
# labels dtype: int64
# ice_mask dtype: bool

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,6))
plt.imshow(ice_mask, cmap="gray")
plt.title("Ice mask (1 = water, 0 = ice)")
plt.axis("off")
plt.show()

# %%
print("Unique labels:", len(np.unique(labels)))
# Out:
# Unique labels: 34
